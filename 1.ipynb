# %%
import pandas as pd
df = pd.read_csv('StudentsPerformance.csv')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
pd.pivot_table(data = df, values = 'math score', index = 'gender',columns = 'race/ethnicity', aggfunc = 'mean')
# Out:
# race/ethnicity    group A    group B    group C    group D    group E
# gender
# female          58.527778  61.403846  62.033333  65.248062  70.811594
# male            63.735849  65.930233  67.611511  69.413534  76.746479

# %%
df.groupby(['gender','race/ethnicity']).count()
# Out:
#                        parental level of education  lunch  \
# gender race/ethnicity
# female group A                                  36     36
#        group B                                 104    104
#        group C                                 180    180
#        group D                                 129    129
#        group E                                  69     69
# male   group A                                  53     53
#        group B                                  86     86
#        group C                                 139    139
#        group D                                 133    133
#        group E                                  71     71
#
#                        test preparation course  math score  reading score  \
# gender race/ethnicity
# female group A                              36          36             36
#        group B                             104         104            104
# ...

# %%
df['lunch'].value_counts()
# Out:
# standard        645
# free/reduced    355
# Name: lunch, dtype: int64

# %%
pd.pivot_table(data = df, values = 'math score', index = 'lunch', columns = 'parental level of education' , aggfunc = 'count')
# Out:
# parental level of education  associate's degree  bachelor's degree  \
# lunch
# free/reduced                                 77                 44
# standard                                    145                 74
#
# parental level of education  high school  master's degree  some college  \
# lunch
# free/reduced                          70               24            79
# standard                             126               35           147
#
# parental level of education  some high school
# lunch
# free/reduced                               61
# standard                                  118

# %%
df['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
pd.pivot_table(data=df,values='math score',index='gender',columns='race/ethnicity',aggfunc='sum')
# Out:
# race/ethnicity  group A  group B  group C  group D  group E
# gender
# female             2107     6386    11166     8417     4886
# male               3378     5670     9398     9232     5449

# %%
df['math score'].sum()
# Out:
# 66089
